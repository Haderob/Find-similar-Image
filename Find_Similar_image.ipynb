# %% [markdown]
# <a href="https://colab.research.google.com/github/Haderob/Find-similar-Image/blob/main/Find_Similar_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install DeepImageSearch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting DeepImageSearch
#   Downloading DeepImageSearch-2.1.tar.gz (7.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting annoy
#   Downloading annoy-1.17.2.tar.gz (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.4/647.4 kB 22.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from DeepImageSearch) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from DeepImageSearch) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from DeepImageSearch) (1.22.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from DeepImageSearch) (2.0.0+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from DeepImageSearch) (4.65.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from DeepImageSearch) (8.4.0)
# Collecting timm
#   Downloading timm-0.6.13-py3-none-any.whl (549 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 42.5 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from DeepImageSearch) (0.15.1+cu118)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->DeepImageSearch) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->DeepImageSearch) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->DeepImageSearch) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->DeepImageSearch) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->DeepImageSearch) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->DeepImageSearch) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->DeepImageSearch) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->DeepImageSearch) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->DeepImageSearch) (2022.7.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from timm->DeepImageSearch) (6.0)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch->DeepImageSearch) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch->DeepImageSearch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch->DeepImageSearch) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch->DeepImageSearch) (3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch->DeepImageSearch) (3.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->DeepImageSearch) (4.5.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->DeepImageSearch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->DeepImageSearch) (16.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision->DeepImageSearch) (2.27.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->DeepImageSearch) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->DeepImageSearch) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch->DeepImageSearch) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->DeepImageSearch) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->DeepImageSearch) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->DeepImageSearch) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->DeepImageSearch) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch->DeepImageSearch) (1.3.0)
# Building wheels for collected packages: DeepImageSearch, annoy
#   Building wheel for DeepImageSearch (setup.py) ... done
#   Created wheel for DeepImageSearch: filename=DeepImageSearch-2.1-py3-none-any.whl size=7782 sha256=10c396e06f20a36a7a38590fe7c1c56e6285b341e5fb07657d1167200562cdb5
#   Stored in directory: /root/.cache/pip/wheels/96/73/ee/ebd27bcfb3ac45ba9d8329196c167d74e05eaffe4c8c14d89c
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.2-cp39-cp39-linux_x86_64.whl size=583509 sha256=ad1923a361df0951b7c923077b52f606376def96394e7a7f33d8f19f37933d73
#   Stored in directory: /root/.cache/pip/wheels/f2/2e/e4/f3ae385c375b87982a2a70055061d4a6330ef4f60817e717e3
# Successfully built DeepImageSearch annoy
# Installing collected packages: annoy, huggingface-hub, timm, DeepImageSearch
# Successfully installed DeepImageSearch-2.1 annoy-1.17.2 huggingface-hub-0.13.4 timm-0.6.13

# %%
from DeepImageSearch import Index,LoadData,SearchImage

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Loading the data

# %%
image_list = LoadData().from_folder(['/content/drive/MyDrive/Colab Notebooks/Similar Image Search/Data'])

# %% [markdown]
# Indexing data

# %%
# For Faster Serching we need to index Data first, After Indexing all the meta data stored on the local path
Index(image_list).start()
# Out:
# 100%|██████████| 69/69 [01:25<00:00,  1.24s/it]
# Image Meta Information Saved: [meta-data-files/image_data_features.pkl]
# 69it [00:01, 55.09it/s]
# Saved the Indexed File:[meta-data-files/image_features_vectors.ann]

# %%
# for searching, you need to give the image path and the number of the similar image you want
SearchImage().get_similar_images(image_path=image_list[0],number_of_images=5)
# Out:
# {0: '/content/drive/MyDrive/Colab Notebooks/Similar Image Search/Data/picture16.png',
#  42: '/content/drive/MyDrive/Colab Notebooks/Similar Image Search/Data/picture14.png',
#  63: '/content/drive/MyDrive/Colab Notebooks/Similar Image Search/Data/picture04.png',
#  23: '/content/drive/MyDrive/Colab Notebooks/Similar Image Search/Data/picture31.png',
#  19: '/content/drive/MyDrive/Colab Notebooks/Similar Image Search/Data/picture35.png'}

# %%
# If you want to plot similar images you can use this method, It will plot 6 most similar images from the data index
SearchImage().plot_similar_images(image_path = image_list[0],number_of_images=6)
